# %% [markdown]
# # import

# %%
import numpy as np
import cv2
import glob
from moviepy.editor import VideoFileClip
from IPython.display import HTML
# camera class

# %%
from camera import *
from line import *

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimage
# %matplotlib inline

# %%
img = mpimage.imread('test_images/test5.jpg')
plt.imshow(img)

# %%
l = Line(img)

# %% [markdown]
# # camera calibration matrix and distortion

# %%
mtx, dist = l.update_mtx_and_dist()

# %% [markdown]
# # Apply a distortion correction to img

# %%
test_img = plt.imread(l.img_path[0])
plt.imshow(test_img)

# %%
undist = l.undistort(test_img)
plt.imshow(undist)

# %% [markdown]
# # Use color transforms, gradients, etc., to create a thresholded binary image.

# %%
combined = l.combined_thresh()

plt.imshow(combined)

# %% [markdown]
# # Apply a perspective transform to rectify binary image ("birds-eye view").

# %%
l.update_M_and_Minv()
# Out:
# (array([[ -4.97409326e-01,  -1.52170409e+00,   9.58341969e+02],
#         [ -4.88498131e-15,  -1.89844560e+00,   8.54300518e+02],
#         [ -5.20417043e-18,  -2.37766264e-03,   1.00000000e+00]]),
#  array([[  1.40625000e-01,  -8.01552644e-01,   5.50000000e+02],
#         [ -3.33066907e-15,  -5.26746725e-01,   4.50000000e+02],
#         [ -6.07153217e-18,  -1.25242601e-03,   1.00000000e+00]]))

# %%
binary_top_down_image = l.transform_perspective(l.M)
plt.imshow(binary_top_down_image)

# %% [markdown]
# # Detect lane pixels and fit to find the lane boundary.

# %%
l.binary_top_down_image = binary_top_down_image

# %%
left_fit, right_fit = l.find_lines(figname= True)

# %% [markdown]
# # Determine the curvature of the lane and vehicle position with respect to center.

# %%
# vehicle position?

# %%
l.curvature(meters=True)
# Out:
# 527.082050244 m 548.338774017 m
# (527.08205024395841, 548.33877401691723)

# %% [markdown]
# # Warp the detected lane boundaries back onto the original image.

# %%
result = l.display()
# Out:
# 1798.15796669 1618.33469752

# %%
plt.imshow(result)

# %%
mtx, dist = camera().update_mtx_and_dist()

# %%
def pipline(img):
    # todo
    # unit the fun name
    l = Line(img)
    l.mtx, l.dist = mtx, dist
    l.combined_thresh() # when consistent?
    l.update_M_and_Minv()
    l.transform_perspective(l.M)
    l.find_lines(figname= True)
    l.curvature(meters= True)
    result = l.display() # need add text
    return(result)

# %%
result = pipline(img)
# Out:
# 665.75709412 m 500.760153617 m
# 1764.3269237 1608.86851221

# %% [markdown]
# # Output visual display of the lane boundaries and numerical estimation of lane curvature and vehicle position.

# %%
input_video = 'project_video.mp4'
clip = VideoFileClip(input_video).subclip(0,1)
# clip2 = VideoFileClip('test_videos/solidYellowLeft.mp4')
output_clip = clip.fl_image(pipline)
# %time output_clip.write_videofile('ouput_' + input_video, audio=False)
# Out:
# 668.587324089 m 576.069301574 m
# 1769.76280851 1519.88186362
# [MoviePy] >>>> Building video ouputproject_video.mp4
# [MoviePy] Writing video ouputproject_video.mp4
#   0%|          | 0/26 [00:00<?, ?it/s]
#   4%|▍         | 1/26 [00:00<00:14,  1.77it/s]
# 495.397422716 m 533.491853518 m
# 1700.73153279 1985.18255088
#   8%|▊         | 2/26 [00:01<00:13,  1.78it/s]
# 596.019878563 m 496.597393101 m
# 1606.59673348 1606.79893511
#  12%|█▏        | 3/26 [00:01<00:12,  1.79it/s]
# 547.594104005 m 645.350583961 m
# 1469.90502184 1543.90287038
